# %% [markdown]
# This exercise is to test your knowledge in
# 1. Input/Output functions
# 2. Decision Making

# %% [markdown]
# # **Exercise 1: Check Even or Odd**
#
# Write a Python program that takes an integer as input and checks whether it is even or odd.

# %%
# prompt user for input
num = int(input("Enter a number: "))

# check if number is odd or even, and display results
if (num % 2 == 0):
  print("The number is an even number.")
else:
  print("The number is an odd number.")
# Out:
# The number is an even number.

# %% [markdown]
# # **Exercise 2: Grade Evaluation**
#
# Write a Python program that takes a score (between 0 and 100) as input and prints the corresponding grade based on the following criteria:
#
# * A for scores 90 and above
# * B for scores 80-89
# * C for scores 70-79
# * D for scores 60-69
# * F for scores below 60

# %%
# prompt user for score
score = int(input("Enter a score between 0 and 100: "))

# evaluate and display results
if ((score >= 0) and (score <=100)):
  if (score >= 90):
    print("The grade for", score, "is A")
  elif (score >= 80):
    print("The grade for", score, "is B")
  elif (score >= 70):
    print("The grade for", score, "is C")
  elif (score >= 60):
    print("The grade for", score, "is D")
  else:
    print("The grade for", score, "is F")
else:
  print("Error! Please enter a score between 0 and 100.")
# Out:
# The grade for 99 is A

# %% [markdown]
# # **Exercise 3: Check Leap Year**
#
# Write a Python program that takes a year as input and checks whether it is a leap year.

# %%
# prompt user for input
year = int(input("Enter a year: "))

# check if year is a leap year, and display results
if (year % 4 == 0 and year % 100 != 0) or (year % 400 == 0):
  print(year, "is a leap year.")
else:
  print(year, "is not a leap year.")
# Out:
# 2020 is a leap year.

# %% [markdown]
# # **Exercise 4: Number Comparison**
#
# Write a program that takes three numbers as input and prints the largest one.

# %%
# prompt user for input
num1 = int(input("Enter the first number: "))
num2 = int(input("Enter the second number: "))
num3 = int(input("Enter the third number: "))

# display the largest number
if ((num1 > num2) and (num1 > num3)):
  print("The largest number is", num1)
elif ((num2 > num1) and (num2 > num3)):
  print("The largest number is", num2)
else:
  print("The largest number is", num3)
# Out:
# The largest number is 10

# %% [markdown]
# # **Exercise 5: Check Vowel or Consonant**
#
# Write a Python program that takes a single character as input and checks whether it is a vowel or consonant.

# %%
# prompt user for input
ch = input("Enter one character: ")

# check if character is vowel or consonant, and display results
if ((ch == "a") or (ch == "A") or (ch == "e") or (ch == "E") or (ch == "i") or (ch == "I") or (ch == "o") or (ch == "O") or (ch == "u") or (ch == "U")):
  print("The character is a vowel.")
else:
  print("The character is a consonant.")
# Out:
# The character is a consonant.

# %% [markdown]
# # **Exercise 6: BMI Calculator**
#
# Write a program that calculates the Body Mass Index (BMI) and categorizes it into different weight statuses. The formula for BMI is weight / height^2, where weight is in kilograms and height is in meters.
#
# Categories:
# * Underweight: BMI < 18.5
# * Normal weight: 18.5 <= BMI < 24.9
# * Overweight: 25 <= BMI < 29.9
# * Obesity: BMI >= 30

# %%
# prompt user for weight and height
weight = float(input("Enter weight in kilograms: "))
height = float(input("Enter height in meters: "))

# calculate BMI
BMI = weight / (height ** 2)

# display weight status category
if (BMI < 18.5):
  print("Your BMI is", BMI, ". Your BMI category is underweight.")
elif (BMI < 24.9):
  print("Your BMI is", BMI, ". Your BMI category is normal weight.")
elif (BMI < 29.9):
  print("Your BMI is", BMI, ". Your BMI category is overweight.")
else:
  print("Your BMI is", BMI, ". Your BMI category is obesity.")
# Out:
# Your BMI is 20.796729893506402 . Your BMI category is normal weight.

# %% [markdown]
# # **Exercise 7: Triangle Type Checker**
#
# Write a program that takes the lengths of three sides of a triangle and determines whether the triangle is equilateral, isosceles, or scalene.
#
# * Equilateral: All three sides are equal.
# * Isosceles: Exactly two sides are equal.
# * Scalene: All three sides are different.

# %%
# prompt user for length of triangle
side1 = int(input("Enter the length of the first side of the triangle: "))
side2 = int(input("Enter the length of the second side of the triangle: "))
side3 = int(input("Enter the length of the third side of the triangle: "))

# determine the triangle type, and display results
if ((side1 == side2) and (side1 == side3)):
  print("The triangle is an equilateral triangle.")
elif (((side1 == side2) and (not side1 == side3)) or ((side1 == side3) and (not side1 == side2)) or ((side2 == side3) and (not side2 == side1))):
  print("The triangle is an isosceles triangle.")
else:
  print("The triangle is a scalene triangle.")
# Out:
# The triangle is an isosceles triangle.

# %% [markdown]
# # **Exercise 8: ATM Withdrawal**
#
# Write a program that simulates an ATM withdrawal. The user enters the withdrawal amount and the program checks if the amount is a multiple of 10. If it is, the program prints the number of each denomination (50, 20, 10) required to dispense the amount. If not, it prints an error message.
#
# For example if the amount is 233 then it must print "4 50 dollar bills, 1 20 dollar bills, 1 10 dollar bills, 3 1 dollar bills".

# %%
# prompt user for withdrawal amount
amount = int(input("Enter your withdrawal amount: "))

# calculate the denominations
amount50 = amount // 50
remainder = amount - (amount50 * 50)
amount20 = remainder // 20
remainder = remainder - (amount20 * 20)
amount10 = remainder // 10
remainder = remainder - (amount10 * 10)
amount1 = remainder // 1

# check the amount and display the denominations
if (amount % 10 == 0):
  print(amount50, "50 dollar bills")
  print(amount20, "20 dollar bills")
  print(amount10, "10 dollar bills")
else:
  print("Error! This ATM machines only withdraws denominations of 50, 20, and 10 dollar bills")
  print(amount50, "50 dollar bills")
  print(amount20, "20 dollar bills")
  print(amount10, "10 dollar bills")
  print(amount1, "1 dollar bills")
# Out:
# Error! This ATM machines only withdraws denominations of 50, 20, and 10 dollar bills
# 4 50 dollar bills
# 1 20 dollar bills
# 1 10 dollar bills
# 3 1 dollar bills

# %% [markdown]
# # **Exercise 9: Adam Number**
#
# Write a Python program to check whether a given number is an Adam number.
#
# An Adam number is a number for which the square of the number and the square of its reverse are themselves reverses of each other. In other words, if you take a number, reverse it, square both the original number and the reversed number, and the results are still reverse of each other, then the original number is called an Adam number.

# %%
# prompt user for a number
num = int(input("Enter a number between 0 and 999: "))

# check if number is maximum 3 digits
if (num >= 0 and num < 1000):
  # square the number
  numsq = num ** 2
  # reverse the number
  if (num < 100): # for 2 digits
    numrev = ((num % 10) * 10) + (num // 10)
  else: # for 3 digits
    numrev = (num % 10) * 100
    numrev = ((num // 10) % 10) * 10 + numrev
    numrev = (num // 100) + numrev
  # square the reversed number
  numrevsq = numrev ** 2
  # reverse the square of the reversed number
  if (numrevsq < 100): # for 2 digits
    reversed = ((numrevsq % 10) * 10) + (numrevsq // 10)
  elif (numrevsq < 1000): # for 3 digits
    reversed = (numrevsq % 10) * 100
    reversed = ((numrevsq // 10) % 10) * 10 + reversed
    reversed = (numrevsq // 100) + reversed
  elif (numrevsq < 10000): # for 4 digits
    reversed = ((numrevsq % 10) * 1000)
    reversed = ((numrevsq // 10) % 10) * 100 + numrevsq
    reversed = ((numrevsq // 100) % 10) * 10 + numrevsq
    reversed = (numrevsq // 1000) + numrevsq
  else: # for 5 digits
    reversed = ((numrevsq % 10) * 10000)
    reversed = ((numrevsq // 10) % 10) * 1000 + numrevsq
    reversed = ((numrevsq // 100) % 10) * 100 + numrevsq
    reversed = ((numrevsq // 1000) % 10) * 10 + numrevsq
    reversed = (numrevsq // 10000) + numrevsq
  # check if square of the number is equals to the reversed of the square of the reversed number
  if (numsq == reversed):
    print(num, "is an Adam Number.")
  else:
    print(num, "is not an Adam Number.")
else:
  print("Error! Enter a number between 0 and 999.")
# Out:
# 12 is an Adam Number.

# %% [markdown]
# # **Exercise 10: Armstrong Number**
#
# Write a Python program to check whether a given number is an Armstrong number.
#
# An Armstrong number (also known as a Narcissistic number or a Pluperfect number) is a number that is equal to the sum of its own digits each raised to the power of the number of digits. For example, 153 is an Armstrong number because 1 ** 3 + 5 ** 3 + 3 ** 3 = 153

# %%
# prompt user for a number
num = int(input("Enter a three digit number: "))

# check condition
if ((num > 99) and (num < 1000)):
  # extract digits
  n1 = num // 100
  n2 = (num // 10) % 10
  n3 = num % 10
  # set the length of number
  numlen = 3
  # calculate the sum of digits to the power of the length of number
  sum = (n1 ** numlen) + (n2 ** numlen) + (n3 ** numlen)
  # check if sum is equals to the number
  if (sum == num):
    print(num, "is an Armstrong number.")
  else:
    print(num, "is not an Armstrong number.")
else:
  print("Please enter a three digit number only.")
# Out:
# 153 is an Armstrong number.
